# %%
import torch
from transformers import LlavaProcessor, LlavaForConditionalGeneration
from PIL import Image
import os

model_id = "llava-hf/llava-1.5-7b-hf"
processor = LlavaProcessor.from_pretrained(model_id)
model = LlavaForConditionalGeneration.from_pretrained(
    model_id,
    torch_dtype=torch.float16,
    low_cpu_mem_usage=True,
    device_map="auto"
)

frame_dir = '/content/drive/MyDrive/intern output/Vid 2'
caption_file = os.path.join(frame_dir, 'captions_llava.txt')

with open(caption_file, 'w') as f:
    for filename in sorted(os.listdir(frame_dir)):
        if filename.endswith('.jpg'):
            image_path = os.path.join(frame_dir, filename)
            image = Image.open(image_path).convert("RGB")

            prompt = "\nDescribe this image in detail."
            inputs = processor(text=prompt, images=image, return_tensors="pt").to("cuda", torch.float16)

            output = model.generate(**inputs, max_new_tokens=100)
            caption = processor.batch_decode(output, skip_special_tokens=True)[0]

            print(f"{filename}: {caption}")
            f.write(f"{filename}: {caption}\n")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/505 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# tokenizer_config.json:   0%|          | 0.00/1.45k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.62M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/41.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/552 [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/674 [00:00<?, ?B/s]
# processor_config.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/701 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/950 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/70.1k [00:00<?, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.18G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/141 [00:00<?, ?B/s]
# frame0.jpg:
# Describe this image in detail.
#
# The image shows a person cutting a piece of food, possibly a cake, using a knife. The person is standing at a table, and the knife is positioned in the middle of the food. The person is wearing a ring on their finger, which is visible as they cut the food. The scene appears to be a close-up of the person and the food, capturing the action of cutting the food.
# frame1.jpg:
# Describe this image in detail.
#
# The image shows a person wearing a ring on their finger, using a spoon to scoop up some white substance, possibly ice cream or whipped cream. The person is standing in front of a table, and the spoon is positioned close to the center of the image. The scene appears to be a casual, everyday moment captured in the photo.
# frame10.jpg:
# Describe this image in detail.
#
# The image shows a person cutting a piece of food on a cutting board. The person is using a knife to cut the food, which appears to be a piece of bread. The knife is positioned towards the right side of the cutting board, and the person is standing on the left side. The cutting board is placed on a dining table, which is visible in the background.
# frame11.jpg:
# Describe this image in detail.
#
# The image shows a person preparing food on a cutting board. They are using a knife to cut a piece of food, which appears to be a piece of pineapple. The person is focused on their task, and the knife is positioned in a way that allows for precise cutting. The cutting board is placed on a countertop, and the scene appears to be set in a kitchen.
# frame12.jpg:
# Describe this image in detail.
#
# The image shows a person preparing food on a cutting board. They are using a knife to cut a piece of food, which appears to be a pineapple. The person is focused on their task, and the knife is positioned in a way that allows for precise cutting. The cutting board is placed on a dining table, which occupies the majority of the scene.
# frame13.jpg:
# Describe this image in detail.
#
# The image shows a person cutting a piece of food, possibly a cake, on a cutting board. The person is using a knife to cut the food, and the knife is positioned towards the right side of the cutting board. The person is focused on the task, and the cutting board is placed on a dining table.
# frame14.jpg:
# Describe this image in detail.
#
# The image shows a person cutting a piece of food, possibly a cake, on a cutting board. The person is using a knife to cut the food, and the knife is positioned in the middle of the cutting process. The cutting board is placed on a dining table, which occupies the majority of the scene. The person is focused on their task, and the scene appears to be well-lit, making it easy to see the details of the food and the
# frame15.jpg:
# Describe this image in detail.
#
# The image shows a person cutting a piece of food on a cutting board. The person is using a knife to cut the food, which appears to be a piece of meat. The cutting board is placed on a dining table, and the person is standing next to it. The scene is focused on the person and the cutting board, with no other objects or people visible in the image.
# frame16.jpg:
# Describe this image in detail.
#
# The image shows a person preparing food on a cutting board. They are using a knife to cut up a piece of food, possibly a pineapple. The person is focused on their task, and the knife is positioned in the middle of the cutting board. The scene appears to be in a kitchen, with the cutting board placed on a countertop.
# frame17.jpg:
# Describe this image in detail.
#
# The image shows a person cutting up a piece of food on a cutting board. The person is using a knife to cut the food into smaller pieces. The cutting board is placed on a dining table, which is the main focus of the scene. The person is standing near the table, and the knife is visible in their hand. The food being cut is located towards the center of the cutting board.
# frame18.jpg:
# Describe this image in detail.
#
# The image shows a person cutting up a piece of food on a cutting board. The person is using a knife to cut the food into smaller pieces. The cutting board is placed on a dining table, which is the main focus of the scene. The person is standing near the table, and the knife is visible in their hand. The food being cut is located in the center of the cutting board.
# frame19.jpg:
# Describe this image in detail.
#
# The image shows a person cutting onions on a cutting board. The person is using a knife to chop the onions, which are spread out on the cutting board. The onions are in various stages of being cut, with some already chopped and others still whole. The person is focused on their task, ensuring that the onions are cut evenly and properly.
# frame2.jpg:
# Describe this image in detail.
#
# The image shows a person preparing food on a counter. They are using a knife to cut a piece of food, which appears to be a piece of cake. The person is standing near the center of the image, and the knife is located towards the right side of the counter. The cake is placed on the left side of the counter, and the person is focused on cutting it.
# frame20.jpg:
# Describe this image in detail.
#
# The image shows a person preparing food on a cutting board. They are using a knife to cut up a piece of food, which appears to be a vegetable. The person is focused on their task, and the knife is positioned in a way that allows for precise cutting. The cutting board is placed on a dining table, which is the main surface for the food preparation.
# frame21.jpg:
# Describe this image in detail.
#
# The image shows a person cutting onions on a cutting board. The person is using a knife to slice the onions, which are spread out on the cutting board. The onions are placed in various positions, with some closer to the person and others further away. The person is focused on their task, and the scene appears to be well-lit, making it easy to see the details of the cutting process.
# frame22.jpg:
# Describe this image in detail.
#
# The image shows a person cutting up a large onion on a cutting board. The person is using a knife to slice the onion into smaller pieces. The onion is placed in the center of the cutting board, and the person is standing to the right of the onion. The scene is focused on the person and the onion, with no other objects or people visible in the image.
# frame23.jpg:
# Describe this image in detail.
#
# The image shows a person cutting onions on a cutting board. The person is using a knife to slice the onions, which are placed on the cutting board. The onions are spread out across the cutting board, with some closer to the person and others further away. The scene captures the process of preparing the onions for cooking.
# frame24.jpg:
# Describe this image in detail.
#
# The image shows a person cutting up a large onion on a cutting board. The person is using a knife to slice the onion into smaller pieces. The onion is placed on a dining table, which occupies the majority of the scene. The person is standing near the table, focused on their task.
# frame25.jpg:
# Describe this image in detail.
#
# The image shows a person cutting up a bunch of onions on a cutting board. The person is using a knife to slice the onions, which are spread out on the cutting board. The onions are in various stages of being cut, with some already sliced and others still whole. The person is focused on their task, and the scene appears to be well-lit, making it easy to see the details of the cutting process.
# frame26.jpg:
# Describe this image in detail.
#
# The image shows a person cutting up a bunch of onions on a cutting board. The person is using a knife to slice the onions, which are spread out on the cutting board. The onions are in various stages of being cut, with some already sliced and others still whole. The person is focused on their task, and the scene appears to be well-lit, making it easy to see the details of the cutting process.
# frame3.jpg:
# Describe this image in detail.
#
# The image shows a person wearing a ring, cutting a piece of food with a knife. The person is standing in front of a dining table, which occupies most of the background. The knife is located towards the right side of the table, while the food is placed on the left side. The person appears to be focused on their task, possibly preparing a meal or a dessert.
# frame4.jpg:
# Describe this image in detail.
#
# The image shows a person in the process of making a cake. They are using a knife to spread frosting on a cake, which is placed on a table. The person is wearing a ring on their finger, and the cake is positioned towards the right side of the table. The scene captures the person's attention as they carefully apply the frosting to the cake.
# frame5.jpg:
# Describe this image in detail.
#
# The image features a person cutting a pizza with a knife. The pizza is placed on a cutting board, and the person is using a knife to slice it into pieces. The person is standing near the pizza, and the knife is positioned above the pizza, ready to cut it. The scene captures the process of preparing a delicious meal.
# frame6.jpg:
# Describe this image in detail.
#
# The image shows a person wearing a watch and a ring, preparing food on a table. They are using a rolling pin to shape a dough ball, which is placed on the table. The person is focused on their task, and the dough ball appears to be in the process of being rolled out. The scene captures the person's attention and dedication to their culinary creation.
# frame7.jpg:
# Describe this image in detail.
#
# The image shows a person preparing food on a cutting board. They are using a knife to cut a piece of food, which appears to be a piece of bread. The person is focused on their task, and the knife is positioned in the middle of the food. The cutting board is placed on a dining table, which occupies the majority of the scene.
# frame8.jpg:
# Describe this image in detail.
#
# The image shows a person's hands preparing food on a cutting board. The person is using a knife to cut a piece of food, possibly a piece of bread or a roll. The knife is located towards the right side of the cutting board, and the person's hands are positioned on the left side. The scene appears to be focused on the food preparation process.
# frame9.jpg:
# Describe this image in detail.
#
# The image shows a person preparing food on a cutting board. They are using a knife to cut a piece of food, possibly a piece of bread or a vegetable. The person is focused on their task, and the knife is positioned in a way that allows for precise cutting. The cutting board is placed on a countertop, and the person is standing next to it.

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
import re
from collections import Counter
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
import nltk
nltk.download('punkt')
nltk.download('stopwords')

with open("/content/drive/MyDrive/intern output/Vid 2/captions_llava.txt", "r") as file:
    text = file.read()

descriptions = []
for line in text.splitlines():
    if re.match(r'^frame\d+\.jpg:', line) or "describe this image" in line.lower():
        continue
    line = line.strip()
    if len(line) > 20:
        descriptions.append(line)

full_text = " ".join(descriptions)

stop_words = set(stopwords.words("english"))
words = word_tokenize(full_text.lower())
filtered_words = [w for w in words if w.isalpha() and w not in stop_words]

freq = Counter(filtered_words)

top_keywords = [word for word, count in freq.most_common(30) if count > 1]

sentences = sent_tokenize(full_text)

important_sentences = [s for s in sentences if any(kw in s.lower() for kw in top_keywords)]
unique_sentences = list(dict.fromkeys(important_sentences))

summary_paragraph = " ".join(unique_sentences[:8])

print("=== Generalized Auto-Generated Summary ===\n")
print(summary_paragraph)
# Out:
# === Generalized Auto-Generated Summary ===
#
# The image shows a person cutting a piece of food, possibly a cake, using a knife. The person is standing at a table, and the knife is positioned in the middle of the food. The person is wearing a ring on their finger, which is visible as they cut the food. The scene appears to be a close-up of the person and the food, capturing the action of cutting the food. The image shows a person wearing a ring on their finger, using a spoon to scoop up some white substance, possibly ice cream or whipped cream. The person is standing in front of a table, and the spoon is positioned close to the center of the image. The scene appears to be a casual, everyday moment captured in the photo. The image shows a person cutting a piece of food on a cutting board.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
